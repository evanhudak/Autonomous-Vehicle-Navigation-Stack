# %%
from navigation.cone_frame import FrameConfig
from navigation.cone_target import ConeNavConfig, compute_target_from_cones
from navigation.pure_pursuit import steer_deg_from_target, steer_percent_from_deg
from navigation.speed_rules import SpeedConfig, compute_speed_commands

# %%
# Example: symmetric cone corridor
cones = [
    (-1.0, 3.0, 0.0, 0.2, 0.2, 0.3),
    ( 1.0, 3.0, 0.0, 0.2, 0.2, 0.3),
    (-1.1, 6.0, 0.0, 0.2, 0.2, 0.3),
    ( 1.1, 6.0, 0.0, 0.2, 0.2, 0.3),
]

# %%
frame_cfg = FrameConfig(
    forward_axis="y",
    forward_sign=1,
    right_sign=1
)

cone_nav_cfg = ConeNavConfig(
    fwd_min_m=0.25,
    fwd_max_m=8.0,
    corridor_width_m=2.0,
    target_fwd_m=3.0,
    use_nearest_n=3
)

speed_cfg = SpeedConfig(
    base_throttle_pct=25,
    min_throttle_pct=10,
    max_throttle_pct=35,
    steering_slow_gain=0.35,
    enable_emergency_stop=True,
    estop_corridor_half_width_m=0.6,
    estop_distance_m=1.2,
    slow_distance_m=2.5,
    brake_pct_estop=90,
    brake_pct_slow=40
)
